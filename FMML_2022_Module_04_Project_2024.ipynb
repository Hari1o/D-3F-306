# %% [markdown]
# <a href="https://colab.research.google.com/github/Hari1o/D-3F-306/blob/main/FMML_2022_Module_04_Project_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FOUNDATIONS OF MODERN MACHINE LEARNING, IIIT Hyderabad**
# ### Project for Module: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

def df(x):
    # [REQUIRED] Define the derivative (slope) of your function here
    return 2 * x - 4  # This is a placeholder, replace it with the actual derivative of your function

def f(x):
    # [REQUIRED] Define your function here
    return x**2 - 4*x + 4  # This is a placeholder, replace it with your actual function

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)  # [REQUIRED] Calculate the gradient at the current x

    # [REQUIRED] Update the value of new_x using gradient descent
    new_x = previous_x - step_multiplier * gradient

    step_size = abs(new_x - previous_x)

    x_list.append(new_x)
    slope_list.append(df(new_x))  # [REQUIRED] Append the slope at the new_x

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 45
# Local minimum occurs at: 2.000034844914373
# Slope or df(x) value at this point is: 6.968982874600016e-05
# f(x) value or cost at this point is: 1.2141683214395016e-09

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming x_1 is defined somewhere in your code
x_1 = np.linspace(-3, 3, 100)

# ... (Previous code remains unchanged)

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-3, 6)  # Adjusted the y-axis limits for better visualization

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)

plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    # [REQUIRED] Define the function g(x)
    return x**2 + np.sin(5*x)

def dg(x):
    # [REQUIRED] Define the derivative (slope) of g(x)
    return 2*x + 5*np.cos(5*x)

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier

# %%
import matplotlib.pyplot as plt
import numpy as np

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**2 + np.sin(5*x)

def dg(x):
    return 2*x + 5*np.cos(5*x)

# Plotting
plt.figure(figsize=[14, 5])

# 1 Chart: Function g(x)
plt.subplot(1, 2, 1)

plt.title('Function g(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)

# 2 Chart: Derivative dg(x)
plt.subplot(1, 2, 2)

plt.title('Derivative dg(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()

plt.plot(x_2, dg(x_2), color='green', linewidth=3, alpha=0.8)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 0.8704044853890083
# Number of steps: 12

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.5,
                                                 multiplier=0.01, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.2910688022501277
# Number of steps: 23

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.29028110385444944
# Number of steps: 9

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 0)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
## TASK-4 : Code the same things as they were done for the first two examples

# %%
# Gradient Descent
new_x = 1.5
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
g_list = [g(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = dg(previous_x)

    new_x = previous_x - step_multiplier * gradient

    step_size = abs(new_x - previous_x)

    x_list.append(new_x)
    g_list.append(g(new_x))

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or dg(x) value at this point is:', dg(new_x))
print('g(x) value or cost at this point is:', g(new_x))

# Plotting
plt.figure(figsize=[20, 5])

# 1 Chart: Function g(x)
plt.subplot(1, 3, 1)

plt.title('Function g(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(x_list, g_list, color='red', s=100, alpha=0.6)

# 2 Chart: Derivative dg(x)
plt.subplot(1, 3, 2)

plt.title('Derivative dg(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()

plt.plot(x_2, dg(x_2), color='green', linewidth=3, alpha=0.8)
plt.scatter(x_list, [dg(x) for x in x_list], color='red', s=100, alpha=0.6)

# 3 Chart: Gradient Descent (close up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()

plt.plot(x_2, dg(x_2), color='green', linewidth=6, alpha=0.8)
plt.scatter(x_list, [dg(x) for x in x_list], color='red', s=300, alpha=0.6)

plt.show()
# Out:
# Local minimum occurs at: 0.6511837307807005
# Slope or dg(x) value at this point is: -3.664992027952872
# g(x) value or cost at this point is: 0.30996313662541364

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  13

# %%
# TASK-5: Run gradient descent 3 times
n = 100

# Run gradient descent with low_gamma
low_gamma_result = gradient_descent(derivative_func=dg, initial_guess=3,
                                    multiplier=0.0005, precision=0.0001, max_iter=n)

# Run gradient descent with mid_gamma
mid_gamma_result = gradient_descent(derivative_func=dg, initial_guess=3,
                                    multiplier=0.001, precision=0.0001, max_iter=n)

# Run gradient descent with high_gamma
high_gamma_result = gradient_descent(derivative_func=dg, initial_guess=3,
                                     multiplier=0.002, precision=0.0001, max_iter=n)

# Print or use the results as needed
print("Low Gamma Result:", low_gamma_result)
print("Mid Gamma Result:", mid_gamma_result)
print("High Gamma Result:", high_gamma_result)
# Out:
# Low Gamma Result: (2.8226903992639873, [3, 2.998899219782147, 2.9977905638234175, 2.99667391789914, 2.995549165997216, 2.9944161902861075, 2.9932748710823303, 2.9921250868174463, 2.990966714004556, 2.989799627204292, 2.9886236989903114, 2.9874387999142904, 2.9862447984704206, 2.9850415610594125, 2.983828951952005, 2.9826068332519893, 2.9813750648587494, 2.9801335044293285, 2.9788820073400237, 2.977620426647523, 2.976348613049591, 2.9750664148453123, 2.973773677894913, 2.972470245579164, 2.971155958758389, 2.9698306557310943, 2.968494172192234, 2.9671463411911403, 2.965786993089135, 2.964415955516851, 2.9630330533312956, 2.961638108572675, 2.9602309404210305, 2.9588113651527044, 2.9573791960966904, 2.9559342435909, 2.954476314938398, 2.9530052143636545, 2.951520742968864, 2.950022698690397, 2.948510876255435, 2.9469850671388707, 2.945445059520527, 2.9438906382427876, 2.94232158476871, 2.940737677140716, 2.9391386899399494, 2.937524394246403, 2.9358945575999194, 2.934248943962184, 2.93
# ...

# %%
# Run gradient descent with low_gamma
low_gamma_result = gradient_descent(derivative_func=dg, initial_guess=3,
                                    multiplier=0.0005, precision=0.0001, max_iter=n)

# Run gradient descent with mid_gamma
mid_gamma_result = gradient_descent(derivative_func=dg, initial_guess=3,
                                    multiplier=0.001, precision=0.0001, max_iter=n)

# Run gradient descent with high_gamma
high_gamma_result = gradient_descent(derivative_func=dg, initial_guess=3,
                                     multiplier=0.002, precision=0.0001, max_iter=n)

# Print or use the results as needed
print("Low Gamma Result:", low_gamma_result)
print("Mid Gamma Result:", mid_gamma_result)
print("High Gamma Result:", high_gamma_result)
# Out:
# Low Gamma Result: (2.8226903992639873, [3, 2.998899219782147, 2.9977905638234175, 2.99667391789914, 2.995549165997216, 2.9944161902861075, 2.9932748710823303, 2.9921250868174463, 2.990966714004556, 2.989799627204292, 2.9886236989903114, 2.9874387999142904, 2.9862447984704206, 2.9850415610594125, 2.983828951952005, 2.9826068332519893, 2.9813750648587494, 2.9801335044293285, 2.9788820073400237, 2.977620426647523, 2.976348613049591, 2.9750664148453123, 2.973773677894913, 2.972470245579164, 2.971155958758389, 2.9698306557310943, 2.968494172192234, 2.9671463411911403, 2.965786993089135, 2.964415955516851, 2.9630330533312956, 2.961638108572675, 2.9602309404210305, 2.9588113651527044, 2.9573791960966904, 2.9559342435909, 2.954476314938398, 2.9530052143636545, 2.951520742968864, 2.950022698690397, 2.948510876255435, 2.9469850671388707, 2.945445059520527, 2.9438906382427876, 2.94232158476871, 2.940737677140716, 2.9391386899399494, 2.937524394246403, 2.9358945575999194, 2.934248943962184, 2.93
# ...

# %%
## TASK-7 : Plot reduction in cost for each iteration

# %%
# TASK-7: Plot reduction in cost for each iteration

# Initialize lists to store cost reduction
cost_reduction_low_gamma = [g(low_gamma[1][0])]  # Initial cost for low_gamma
cost_reduction_mid_gamma = [g(mid_gamma[1][0])]  # Initial cost for mid_gamma
cost_reduction_high_gamma = [g(high_gamma[1][0])]  # Initial cost for high_gamma
cost_reduction_insane_gamma = [g(insane_gamma[1][0])]  # Initial cost for insane_gamma

# Run gradient descent and track cost reduction for low_gamma
for i in range(1, len(low_gamma[1])):
    cost_reduction_low_gamma.append(cost_reduction_low_gamma[-1] - g(low_gamma[1][i]))

# Run gradient descent and track cost reduction for mid_gamma
for i in range(1, len(mid_gamma[1])):
    cost_reduction_mid_gamma.append(cost_reduction_mid_gamma[-1] - g(mid_gamma[1][i]))

# Run gradient descent and track cost reduction for high_gamma
for i in range(1, len(high_gamma[1])):
    cost_reduction_high_gamma.append(cost_reduction_high_gamma[-1] - g(high_gamma[1][i]))

# Run gradient descent and track cost reduction for insane_gamma
for i in range(1, len(insane_gamma[1])):
    cost_reduction_insane_gamma.append(cost_reduction_insane_gamma[-1] - g(insane_gamma[1][i]))

# Plotting
plt.figure(figsize=[15, 5])

# Chart: Cost reduction for each iteration
plt.title('Cost Reduction for Each Iteration', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost Reduction', fontsize=16)

plt.plot(cost_reduction_low_gamma, label='low_gamma', color='red')
plt.plot(cost_reduction_mid_gamma, label='mid_gamma', color='orange')
plt.plot(cost_reduction_high_gamma, label='high_gamma', color='green')
plt.plot(cost_reduction_insane_gamma, label='insane_gamma', color='purple')

plt.legend()
plt.show()

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
## TASK-8 : Code the same things as they were done for the first two examples

# %%
# Gradient Descent Function
def gradient_descent_g(derivative_func, initial_guess, multiplier, precision, max_iter):
    x = initial_guess
    x_list = [x]
    cost_list = [g(x)]

    for n in range(max_iter):
        gradient = derivative_func(x)
        x = x - multiplier * gradient

        x_list.append(x)
        cost_list.append(g(x))

        if abs(gradient) < precision:
            break

    return x_list, cost_list

# Run gradient descent for g(x) with the new function
n = 100
low_gamma_g = gradient_descent_g(derivative_func=dg, initial_guess=3,
                                 multiplier=0.0005, precision=0.0001, max_iter=n)

mid_gamma_g = gradient_descent_g(derivative_func=dg, initial_guess=3,
                                 multiplier=0.001, precision=0.0001, max_iter=n)

high_gamma_g = gradient_descent_g(derivative_func=dg, initial_guess=3,
                                  multiplier=0.002, precision=0.0001, max_iter=n)

insane_gamma_g = gradient_descent_g(derivative_func=dg, initial_guess=1.9,
                                     multiplier=0.25, precision=0.0001, max_iter=n)

# Plotting
plt.figure(figsize=[20, 5])

# 1 Chart: Function g(x)
plt.subplot(1, 3, 1)

plt.title('Function g(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(low_gamma_g[0], low_gamma_g[1], color='red', s=100, alpha=0.6, label='low_gamma')
plt.scatter(mid_gamma_g[0], mid_gamma_g[1], color='orange', s=100, alpha=0.6, label='mid_gamma')
plt.scatter(high_gamma_g[0], high_gamma_g[1], color='green', s=100, alpha=0.6, label='high_gamma')
plt.scatter(insane_gamma_g[0], insane_gamma_g[1], color='purple', s=100, alpha=0.6, label='insane_gamma')
plt.legend()

# 2 Chart: Derivative dg(x)
plt.subplot(1, 3, 2)

plt.title('Derivative dg(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()

plt.plot(x_2, dg(x_2), color='green', linewidth=3, alpha=0.8)
plt.scatter(low_gamma_g[0], [dg(x) for x in low_gamma_g[0]], color='red', s=100, alpha=0.6)
plt.scatter(mid_gamma_g[0], [dg(x) for x in mid_gamma_g[0]], color='orange', s=100, alpha=0.6)
plt.scatter(high_gamma_g[0], [dg(x) for x in high_gamma_g[0]], color='green', s=100, alpha=0.6)
plt.scatter(insane_gamma_g[0], [dg(x) for x in insane_gamma_g[0]], color='purple', s=100, alpha=0.6)

# 3 Chart: Gradient Descent (close up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()

plt.plot(x_2, dg(x_2), color='green', linewidth=6, alpha=0.8)
plt.scatter(low_gamma_g[0], [dg(x) for x in low_gamma_g[0]], color='red', s=300, alpha=0.6)
plt.scatter(mid_gamma_g[0], [dg(x) for x in mid_gamma_g[0]], color='orange', s=300, alpha=0.6)
plt.scatter(high_gamma_g[0], [dg(x) for x in high_gamma_g[0]], color='green', s=300, alpha=0.6)
plt.scatter(insane_gamma_g[0], [dg(x) for x in insane_gamma_g[0]], color='purple', s=300, alpha=0.6)

plt.show()

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np

# Define the function (replace with your actual function)
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# Define your data (replace with your actual data)
x_4 = np.linspace(-5, 5, 100)
y_4 = np.linspace(-5, 5, 100)
x_4, y_4 = np.meshgrid(x_4, y_4)
z_4 = f(x_4, y_4)

# Generating 3D Plot
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, z_4, cmap=cm.coolwarm, alpha=0.4)

plt.show()

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
from sympy import symbols, diff

a, b = symbols('a b')

# Assuming you have defined f(a, b) somewhere
# Replace the following line with your actual function definition
f = a**2 + b**2

print('Our cost function f(a, b) is: ', f)
print('Partial derivative wrt b is: ', diff(f, b))
print('Value of f(a, b) at a=1.8, b=1.0 is: ',
      f.evalf(subs={a: 1.8, b: 1.0}))  # Python Dictionary
print('Value of partial derivative wrt a: ', diff(f, a).evalf(subs={a: 1.8, b: 1.0}))
# Out:
# Our cost function f(a, b) is:  a**2 + b**2
# Partial derivative wrt b is:  2*b
# Value of f(a, b) at a=1.8, b=1.0 is:  4.24000000000000
# Value of partial derivative wrt a:  3.60000000000000

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
import numpy as np
from sympy import symbols, diff

# Define your cost function
a, b = symbols('a b')
f = a**2 + b**2  # Replace with your actual cost function

# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])  # initial guess

for n in range(max_iter):
    gradient_x = diff(f, a).evalf(subs={a: params[0], b: params[1]})
    gradient_y = diff(f, b).evalf(subs={a: params[0], b: params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f.subs({a: params[0], b: params[1]}))
# Out:
# Values in gradient array: [1.57835979496953e-48 8.76866552760853e-49]
# Minimum occurs at x value of:  6.31343917987813e-49
# Minimum occurs at y value of:  3.50746621104341e-49
# The cost is:  5.21618334996315e-97

# %%
##########################
##########################

## TASK-10 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Partial derivative functions example 4
def fpx(x, y):
    return ## [REQUIRED]

def fpy(x, y):
    return ## [REQUIRED]

# %%
import sympy as sp

# Define symbols
x, y = sp.symbols('x y')

# Example function f(x, y) - Replace this with your actual function
f = x**2 + y**3

# Partial derivatives
fpx = sp.diff(f, x)
fpy = sp.diff(f, y)

# Print the partial derivatives
print("Partial derivative with respect to x (f_x):", fpx)
print("Partial derivative with respect to y (f_y):", fpy)
# Out:
# Partial derivative with respect to x (f_x): 2*x
# Partial derivative with respect to y (f_y): 3*y**2

# %%
import numpy as np
from sympy import symbols, diff

# Define symbols
x, y = symbols('x y')

# Example cost function - Replace this with your actual cost function
f = x**2 + y**2

# Partial derivatives
fpx = diff(f, x)
fpy = diff(f, y)

# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])  # initial guess

# Gradient descent loop
for n in range(max_iter):
    gradient_x = fpx.evalf(subs={x: params[0], y: params[1]})
    gradient_y = fpy.evalf(subs={x: params[0], y: params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f.evalf(subs={x: params[0], y: params[1]}))
# Out:
# Values in gradient array: [1.57835979496953e-48 8.76866552760853e-49]
# Minimum occurs at x value of:  6.31343917987813e-49
# Minimum occurs at y value of:  3.50746621104341e-49
# The cost is:  5.21618334996315e-97

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
import numpy as np
from sympy import symbols, diff

# Define symbols
x, y = symbols('x y')

# Example cost function - Replace this with your actual cost function
f = x**2 + y**2

# Partial derivatives
fpx = diff(f, x)
fpy = diff(f, y)

# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0])  # initial guess
values_array = params.reshape(1, 2)
gradients_array = []

for n in range(max_iter):
    gradient_x = fpx.evalf(subs={x: params[0], y: params[1]})
    gradient_y = fpy.evalf(subs={x: params[0], y: params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)
    gradients_array.append(gradients)

# Results
print('Values in gradient array:', gradients_array[-1])  # Print the last set of gradients
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f.evalf(subs={x: params[0], y: params[1]}))
# Out:
# Values in gradient array: [1.86728200599645e-19 1.03737889222025e-19]
# Minimum occurs at x value of:  7.46912802398578e-20
# Minimum occurs at y value of:  4.14951556888100e-20
# The cost is:  7.30063528950756e-39

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029545
# Theta 1: 1.2227264637835913

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [0.94796558]
# MSE regression using manual calc is 0.947965575979458
# MSE regression is 0.9479655759794577

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.9483826526747164
# Min occurs at (i,j): (111, 91)
# Min MSE for Theta 0 at plot_t0[111][91] 0.829145728643216
# Min MSE for Theta 1 at plot_t1[111][91] 1.2311557788944723

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.8532230461743415
# Min occurs at Theta 1: 1.2214935332607393
# MSE is: [0.94797511]

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
